# %%
from clase import cuartas 
import matplotlib.pyplot as plt

# %%
path_midi1 =  '../Archivos/XML_ejemplos/MIDI1.xml'

midi1 = cuartas(path_midi1)
midi1.extraer_df()
# Out:
#               Notas Intervalos Nombre intervalo simplificado Num_semitonos  \
# 0  [C3, C4, G4, E5]  [8, 5, 3]                  [P8, P5, M3]  [12, 19, 28]
# 1  [D3, B3, G4, D5]  [8, 6, 4]                  [M6, P4, P8]   [9, 17, 24]
# 2  [E3, C4, G4, C5]  [6, 6, 3]                  [m6, m3, m6]   [8, 15, 20]
# 3  [F3, D4, F4, B4]  [8, 6, 4]                  [M6, P8, A4]   [9, 12, 18]
# 4  [E3, E4, G4, C5]  [8, 6, 3]                  [P8, m3, m6]  [12, 15, 20]
# 5  [G3, E4, G4, C5]  [8, 6, 4]                  [M6, P8, P4]   [9, 12, 17]
# 6  [G3, D4, G4, B4]  [8, 5, 3]                  [P5, P8, M3]   [7, 12, 16]
# 7  [C3, E4, G4, C5]  [8, 5, 3]                  [M3, P5, P8]  [16, 19, 24]
# 8  [C3, F4, A4, C5]  [8, 6, 4]                  [P4, M6, P8]  [17, 21, 24]
# 9  [C3, E4, G4, C5]  [8, 5, 3]                  [M3, P5, P8]  [16, 19, 24]
#
#                          Nombre intervalo completo  Beat  Compás  Duración  \
# ...

# %%
tiempos_path = '../Archivos/XML_ejemplos/Ensayo_XML_UbicacionTiempos.musicxml'

tiempos = cuartas(tiempos_path)
tiempos.mostrar_partitura()

# %%
tiempos.extraer_df()
# Out:
#               Notas Intervalos Nombre intervalo simplificado Num_semitonos  \
# 0  [C3, C4, G4, E5]  [8, 5, 3]                  [P8, P5, M3]  [12, 19, 28]
# 1  [D3, B3, G4, D5]  [8, 6, 4]                  [M6, P4, P8]   [9, 17, 24]
# 2  [E3, C4, G4, C5]  [6, 6, 3]                  [m6, m3, m6]   [8, 15, 20]
# 3  [F3, C4, A4, C5]  [5, 5, 3]                  [P5, M3, P5]   [7, 16, 19]
# 4  [F3, F4, A4, C5]  [8, 5, 3]                  [P8, M3, P5]  [12, 16, 19]
# 5  [G3, E4, G4, C5]  [8, 6, 4]                  [M6, P8, P4]   [9, 12, 17]
# 6  [G3, D4, G4, B4]  [8, 5, 3]                  [P5, P8, M3]   [7, 12, 16]
# 7  [C3, E4, G4, C5]  [8, 5, 3]                  [M3, P5, P8]  [16, 19, 24]
# 8  [C3, F4, A4, C5]  [8, 6, 4]                  [P4, M6, P8]  [17, 21, 24]
# 9  [C3, E4, G4, C5]  [8, 5, 3]                  [M3, P5, P8]  [16, 19, 24]
#
#                        Nombre intervalo completo  Beat  Compás  Duración  \
# ...

# %%
#Ejemplo tresillos

tresillos_path = '../Archivos/XML_ejemplos/Ensayo_XML_UbicacionTiemposTresillos.musicxml'
tresillos = cuartas(tresillos_path)
tresillos.extraer_df()
# Out:
#               Notas Intervalos Nombre intervalo simplificado Num_semitonos  \
# 0  [C3, G3, E4, C5]  [8, 5, 3]                  [P5, M3, P8]   [7, 16, 24]
# 1  [E3, G3, C4, C5]  [6, 6, 3]                  [m3, m6, m6]    [3, 8, 20]
# 2  [F3, A3, D4, C5]  [6, 5, 3]                  [M3, M6, P5]    [4, 9, 19]
# 3  [E3, A3, E4, C5]  [8, 6, 4]                  [P4, P8, m6]   [5, 12, 20]
# 4  [D3, A3, F4, C5]  [7, 5, 3]                  [P5, m3, m7]   [7, 15, 22]
# 5  [G2, G3, F4, B4]  [8, 7, 3]                  [P8, m7, M3]  [12, 22, 28]
# 6  [C3, G3, E4, C5]  [8, 5, 3]                  [P5, M3, P8]   [7, 16, 24]
# 7  [D3, G3, D4, B4]  [8, 6, 4]                  [P4, P8, M6]   [5, 12, 21]
# 8  [E3, G3, C4, C5]  [6, 6, 3]                  [m3, m6, m6]    [3, 8, 20]
# 9  [C3, G3, E4, C5]  [8, 5, 3]                  [P5, M3, P8]   [7, 16, 24]
#
#                        Nombre intervalo completo  Beat  Compás Duración  \
# ...

# %%
#Ejemplo compás ternario

compas_ternario_path = '../Archivos/XML_ejemplos/Ensayo_XML_UbicacionTiemposCompasTernario.musicxml'
compas_ternario = cuartas(compas_ternario_path)
compas_ternario.extraer_df()
# Out:
#               Notas Intervalos Nombre intervalo simplificado Num_semitonos  \
# 0  [C3, C4, G4, E5]  [8, 5, 3]                  [P8, P5, M3]  [12, 19, 28]
# 1  [D3, B3, G4, D5]  [8, 6, 4]                  [M6, P4, P8]   [9, 17, 24]
# 2  [E3, C4, G4, C5]  [6, 6, 3]                  [m6, m3, m6]   [8, 15, 20]
# 3  [F3, C4, A4, C5]  [5, 5, 3]                  [P5, M3, P5]   [7, 16, 19]
# 4  [F3, F4, A4, C5]  [8, 5, 3]                  [P8, M3, P5]  [12, 16, 19]
# 5  [G3, E4, G4, C5]  [8, 6, 4]                  [M6, P8, P4]   [9, 12, 17]
# 6  [G3, D4, G4, B4]  [8, 5, 3]                  [P5, P8, M3]   [7, 12, 16]
# 7  [C3, E4, G4, C5]  [8, 5, 3]                  [M3, P5, P8]  [16, 19, 24]
# 8  [C3, F4, A4, C5]  [8, 6, 4]                  [P4, M6, P8]  [17, 21, 24]
# 9  [C3, E4, G4, C5]  [8, 5, 3]                  [M3, P5, P8]  [16, 19, 24]
#
#                        Nombre intervalo completo  Beat  Compás  Duración  \
# ...

# %%
#Ejemplo coral Bach
bach_path = '../Archivos/Corales/028600B_.xml'
bach = cuartas(bach_path)
bach.mostrar_partitura()
df = bach.extraer_df()

df
# Out:
#                 Notas Intervalos Nombre intervalo simplificado Num_semitonos  \
# 0    [A2, C4, E4, A4]  [8, 5, 3]                  [m3, P5, P8]  [15, 19, 24]
# 1    [A3, E4, A4, C5]  [8, 5, 3]                  [P5, P8, m3]   [7, 12, 15]
# 2        [A3, E4, B4]     [5, 2]                      [P5, M2]       [7, 14]
# 3       [G#3, E4, B4]     [6, 3]                      [m6, m3]       [8, 15]
# 4    [A3, E4, B4, C5]  [5, 3, 2]                  [P5, M2, m3]   [7, 14, 15]
# 5    [A2, E4, A4, C5]  [8, 5, 3]                  [P5, P8, m3]  [19, 24, 27]
# 6    [B2, D4, A4, D5]  [7, 3, 3]                  [m3, m7, m3]  [15, 22, 27]
# 7    [B2, D4, G4, D5]  [6, 3, 3]                  [m3, m6, m3]  [15, 20, 27]
# 8    [C3, D4, G4, E5]  [5, 3, 2]                  [M2, P5, M3]  [14, 19, 28]
# 9    [D3, C4, G4, E5]  [7, 4, 2]                  [m7, P4, M2]  [10, 17, 26]
# 10   [D3, B3, G4, E5]  [6, 4, 2]                  [M6, P4, M2]   [9, 17, 26]
# ...

# %%
bach.mostrar_partitura()

# %%
# df['Intervalos']


# contiene_patron = [any(lista[i:i+2] == [6, 4] for i in range(len(lista))) for lista in df.Intervalos]
# df_filtrado = df[contiene_patron]
# df_filtrado

# %%
# #FUNCION
# def CuartaseIntervalos(dataframe):
#   nuevalista = dataframe['Intervalos']
#   info_filas = []
#   indices = []
#   for indice, lista in enumerate(nuevalista):
#     if 6 in lista and 4 in lista:
#       #FILAS E INFORMACION
#       fila = dataframe.iloc[indice]
#       info_filas.append(fila)
#       #INDICES PARA ACCEDER POR FUERA
#       indice_fila = indice
#       indices.append(indice_fila)

#   return indices

# %%
#Función para encontrar que intervalos tienen el 6/4 (Garantizando que sea 4 justa)


def CuartaseIntervalos4(dataframe):
  nuevalista = dataframe['Nombre intervalo simplificado']
  # info_filas = []
  indices = []
  for indice, lista in enumerate(nuevalista):
    if ('M6' in lista or 'm6' in lista) and 'P4' in lista:
      #FILAS E INFORMACION
      fila = dataframe.iloc[indice]
      # info_filas.append(fila)
      #INDICES PARA ACCEDER POR FUERA
      indice_fila = indice
      indices.append(indice_fila)

  return indices

# %%
#Función encontrar voces dentro del 6/4 

def voces_64(df):

    """
    Función que encuentra las voces que contienen el intervalo 6/4 en un dataframe de pandas

    Parameters
    ----------
    df : dataframe
        Dataframe de pandas con información de los acordes de la partitura

    Returns

    n_indice4 : list
        Lista con los índices de las voces que contienen el intervalo de cuarta justa
    n_indice6 : list
        Lista con los índices de las voces que contienen el intervalo de sexta mayor o menor

        
    """
    nuevalista = df['Nombre intervalo simplificado']
    n_indice4 = []
    n_indice6 = []
    a = df['Nombre intervalo simplificado'].tolist()
    for j in a:
        
            voz = j
            indice4 = voz.index('P4') +1
            
            if 'm6' in voz:
                indice6 = voz.index('m6') + 1
            if 'M6' in voz:
                indice6 = voz.index('M6') + 1
            n_indice4.append(indice4)
            n_indice6.append(indice6)
        

    return n_indice4 , n_indice6

# %%
lista_64 = CuartaseIntervalos4(df)
lista_antes = [i-1  for i in lista_64]
lista_despues =   [i+1  for i in lista_64]

df_filtrado = df.iloc[lista_64]
df_antes = df.iloc[lista_antes]
df_despues = df.iloc[lista_despues]

# %%
ind4 , ind6 = voces_64(df_filtrado)
ind4, ind6
# Out:
# ([2, 3, 2], [1, 1, 3])

# %%
df_filtrado
# Out:
#                Notas Intervalos Nombre intervalo simplificado Num_semitonos  \
# 10  [D3, B3, G4, E5]  [6, 4, 2]                  [M6, P4, M2]   [9, 17, 26]
# 31  [G3, E4, A4, C5]  [6, 4, 2]                  [M6, M2, P4]   [9, 14, 17]
# 34  [E3, E4, A4, C5]  [8, 6, 4]                  [P8, P4, m6]  [12, 17, 20]
#
#                         Nombre intervalo completo  Beat  Compás  Duración  \
# 10    [Major Sixth, Perfect Fourth, Major Second]  1.75       2      0.25
# 31    [Major Sixth, Major Second, Perfect Fourth]  2.50       5      0.50
# 34  [Perfect Octave, Perfect Fourth, Minor Sixth]  4.00       5      1.00
#
#        Tipo
# 10     16th
# 31   eighth
# 34  quarter

# %%
ind4
# Out:
# [2, 3, 2]

# %%
#Extraer nota del bajo de los acordes 

def extraer_bajo(dataframe):

    """ 
    Función que extrae las notas del bajo de los acordes 6/4 del dataframe
    
    Parameters
    ----------
    dataframe : DataFrame
        Dataframe de los acordes de la partitura
        
    Returns
    -------
    bajos : list
        Lista con las notas del bajo de los acordes 6/4
    
    """
    
    nuevalista = dataframe['Notas']
    bajos = []
    for lista in nuevalista:
        bajos.append(lista[0][0])

    return bajos

bajos = extraer_bajo(df.iloc[lista_64])
bajos
# Out:
# ['D', 'G', 'E']

# %%
#Extraer nota del bajo de los acordes 

def extraer_n4_n6(dataframe,indice4,indice6):

    """ 
    Función que extrae las notas de la cuarta y sexta de los acordes 6/4 del dataframe filtrado

    Parameters

    ----------

    dataframe : DataFrame

        Dataframe filtrado de los acordes de la partitura

    indice4 : list

        Lista con los índices de las voces que contienen el intervalo de cuarta justa

    indice6 : list

        Lista con los índices de las voces que contienen el intervalo de sexta mayor o menor

    Returns

    -------

    cuartas : list

        Lista con las notas de la cuarta de los acordes 6/4


    sextas : list

        Lista con las notas de la sexta de los acordes 6/4
         
    
    """
   
    cuartas = []
    sextas = []
    for i in range(0,len(indice4)):
        not4 = dataframe.iloc[i]['Notas'][ind4[i]][:-1]
        not6 = dataframe.iloc[i]['Notas'][ind6[i]][:-1]
        cuartas.append(not4) 
        sextas.append(not6)  
        
    return cuartas, sextas 

N4sb, N6sb = extraer_n4_n6(df.iloc[lista_64],ind4,ind6)

# %%
df.iloc[lista_64]['Notas'].tolist()[0]
# Out:
# ['D3', 'B3', 'G4', 'E5']

# %%
def notas_bajos(df,lista_indice):
    
    """ 
    Función que extrae las notas del bajo de los acordes de una lista de índices de un dataframe
    la lista es la correspondiente a los acordes 6/4
    El dataframe es el dataframe de todos los acordes de la partirura 
    que se está analizando. Devuelve una lista con las notas del bajo antes y después de los acordes 6/4 

    Parameters
    ----------
    df : DataFrame
        Dataframe de los acordes de la partitura

    lista_indice : list
        Lista de índices de los acordes 6/4

    Returns
    -------
    BB_n : list
        Lista con las notas del bajo de los acordes antes de los acordes 6/4

    BA_n : list
        Lista con las notas del bajo de los acordes después de los acordes 6/4


    """
    
    
    BB_n = []
    BA_n = []

    for j in lista_indice:

        BB_notas = []
        for i in range(1,5):
            NB = df.iloc[j]['Notas'][0][0]
            BB = df.iloc[j-i]['Notas'][0][0]
            
            # BB_notas.append(NB)
            BB_notas.append(BB)
            if NB != BB:
                break
        BB_n.append(BB_notas)

        BA_notas = []

        for i in range(1,5):
            NB = df.iloc[j]['Notas'][0][0]
            BA = df.iloc[j+i]['Notas'][0][0]

            # BB_notas.append(NB)
            BA_notas.append(BA)
            if NB != BA:
                break
        BA_n.append(BA_notas)

    return BB_n, BA_n

    # df.iloc[lista_64[j]-i]['Notas'][ind4[j]][0]
        

BB_n, BA_n = notas_bajos(df,lista_64)
BB_n, BA_n
# Out:
# ([['D', 'C'], ['A'], ['F']], [['E'], ['F'], ['D']])

# %%
len(df)
# Out:
# 40

# %%
def notas_voces(df,ind4,ind6,BB_n,BA_n,lista_64):
    
    """ 
    Función que extrae las notas de las voces (4 y 6) de los acordes antes y después de los acordes 6/4
    El dataframe es el dataframe de todos los acordes de la partirura 
    que se está analizando. Devuelve una lista con las notas de las voces antes y después de los
    acordes 6/4 para la cuarta y la sexta

    Parameters
    ----------
    df : DataFrame
        Dataframe de los acordes de la partitura

    ind4 : list
        Lista de índices de las voces 4

    ind6 : list
        Lista de índices de las voces 6

    BB_n : list
        Lista con las notas del bajo de los acordes antes de los acordes 6/4

    BA_n : list
        Lista con las notas del bajo de los acordes después de los acordes 6/4

    lista_64 : list
        Lista de índices de los acordes 6/4

    Returns
    -------
    voces4b : list
        Lista con las notas de la cuarta antes de los acordes 6/4

    voces4a : list
        Lista con las notas de la cuarta  después de los acordes 6/4

    voces6b : list
        Lista con las notas de la sexta  antes de los acordes 6/4

    voces6a : list
        Lista con las notas de la sexta después de los acordes 6/4


        

    """

    voces4b = []
    voces4a = []
    voces6b = []
    voces6a = []


    for j in range(len(ind4)):
        notas4b = []
        notas6b = []
        Notas4 = []
        Notas6 = []

        
        
        for i in range(1,len(BB_n[j])+1):
            N4b = df.iloc[lista_64[j]-i]['Notas'][ind4[j]][:-1]
            N6b = df.iloc[lista_64[j]-i]['Notas'][ind6[j]][:-1]
            
            notas4b.append(N4b)
            notas6b.append(N6b)

            
        voces4b.append(notas4b)
        voces6b.append(notas6b)

        notas4a = []
        notas6a = []

        for i in range(1,len(BA_n[j])+1):
            N4a = df.iloc[lista_64[j]+i]['Notas'][ind4[j]][:-1]
            N6a = df.iloc[lista_64[j]+i]['Notas'][ind6[j]][:-1]
            notas4a.append(N4a)
            notas6a.append(N6a)
    
            
        voces4a.append(notas4a)
        voces6a.append(notas6a)

    return voces4b, voces4a, voces6b, voces6a

# %%
V4b, V4a, V6b, V6a = notas_voces(df,ind4,ind6,BB_n,BA_n,lista_64)
V4b, V4a, V6b, V6a
# Out:
# ([['G', 'G'], ['C'], ['G#']],
#  [['G'], ['D'], ['A']],
#  [['C', 'D'], ['E'], ['D']],
#  [['C'], ['D'], ['B']])

# %%
acordes = df_filtrado['Notas'].tolist()

import pandas as pd
dict = {'Acorde': acordes, 'Bajos antes' : BB_n , 'Notas 4(antes)' : V4b , 'Notas 6(antes)': V6b
        , 'Bajos despues': BA_n , 'Notas 4(despues)' : V4a , 'Notas 6(despues)': V6a }
dataframe = pd.DataFrame(dict)
dataframe
# Out:
#              Acorde Bajos antes Notas 4(antes) Notas 6(antes) Bajos despues  \
# 0  [D3, B3, G4, E5]      [D, C]         [G, G]         [C, D]           [E]
# 1  [G3, E4, A4, C5]         [A]            [C]            [E]           [F]
# 2  [E3, E4, A4, C5]         [F]           [G#]            [D]           [D]
#
#   Notas 4(despues) Notas 6(despues)
# 0              [G]              [C]
# 1              [D]              [D]
# 2              [A]              [B]

# %% [markdown]
# ##### Función para verificar las condiciones de 6/4 de paso

# %%
from music21 import *
import numpy as np

# %%
#Listas con los intervalos entre bb y nb y ba y nb

inter_BA = []
inter_BB = []

cond3 = []

cond4 = []

for i in range(len(bajos)):

    bb = BB_n[i][-1]
    ba = BA_n[i][-1]
    nb = bajos[i]

    n4sb = N4sb[i]
    n6sb = N6sb[i]

    n4bb = V4b[i][-1]
    n6bb = V6b[i][-1]

    n4ba = V4a[i][-1]
    n6ba = V6a[i][-1]


    #Definir las notas

    bb = note.Note(bb)
    ba = note.Note(ba)
    nb = note.Note(nb)

    #Definir los intervalos entre BB Y NB y BA Y NB

    int_b = interval.notesToInterval(bb,nb)
    int_a = interval.notesToInterval(ba,nb)

    inter_BA.append(int_a.semiSimpleName)
    inter_BB.append(int_b.semiSimpleName)

    #SEGUNDA CONDICION
    if (bb<nb and ba>nb) or (bb>nb and ba<nb):
        cond3.append(True)
    else:
        cond3.append(False)

    #TERCERA CONDICION
    if (n4sb == n4bb) and (n4sb == n4ba):
        cond4.append(True)
    else:
        cond4.append(False)


#Verificar si son segunda menor

seg_m_b = [i == 'm2' for i in inter_BB]
seg_m_a = [i == 'm2' for i in inter_BA]


seg_m_b, seg_m_a = np.array(seg_m_b), np.array(seg_m_a)
cond3 = np.array(cond3)
cond4 = np.array(cond4)

# %%
cond3
# Out:
# array([ True,  True,  True])

# %%
np.sum([cond3,cond4,seg_m_a,seg_m_b],axis=0)
# Out:
# array([2, 1, 2])

# %% [markdown]
# df es el dataframe completo

# %% [markdown]
# 1. Necesito construir un dataframe que sea dfantes, a partir de las notas de los bajos que cambiaron.
# 2. a ese dataframe hacerle esto : df_antes.index.tolist(), que saca los indices
# 3. recorrer el ese nuevo dataframe, y buscar en la lista de las notas, la posicion que corresponda al indice de la lista de indices4
# 4. lo mismo para las 6 y para cada uno

# %% [markdown]
# -------------------------------

# %%
plt.hist(df_filtrado['Beat'], bins=16, label='Filtrado', alpha=0.5)
plt.hist(df_antes['Beat'], bins=16 , label='Antes', alpha=0.5)
plt.hist(df_despues['Beat'], bins=16, label='Despues', alpha=0.5)
plt.xlabel('Beat')
plt.ylabel('Frecuencia')
plt.title('Histograma de los beats')
plt.legend(loc='upper right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a figure and a set of subplots
fig, ax = plt.subplots(3, 1, figsize=(10, 10))
# Plot the first histogram
plt.subplot(3, 1, 1)  # Create the first subplot (3 rows, 1 column, first position)
plt.hist(df_filtrado['Beat'], bins=20, label='Filtrado')
plt.xlabel('Beat')  # Add x-axis label for clarity
# plt.xticks(np.arange(1, 5, .25))
plt.title('Acorde 6/4')  # Optional individual title

# Plot the second histogram
plt.subplot(3, 1, 2)  # Second subplot
plt.hist(df_antes['Beat'], bins=20, label='Antes')
plt.xlabel('Beat')  # Add x-axis label for clarity
plt.title('Acorde Antes')  # Optional individual title

# Plot the third histogram
plt.subplot(3, 1, 3)  # Third subplot
plt.hist(df_despues['Beat'], bins=20, label='Despues')
plt.xlabel('Beat')  # Add x-axis label for clarity
plt.title('Acorde Despues')  # Optional individual title

# Add overall title and y-axis label for the figure
plt.suptitle('Histograma de los beats', fontsize=16)
plt.subplots_adjust(hspace=0.4)  # Adjust spacing between subplots
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# ------------------------------

# %%
df_filtrado
# Out:
#                Notas Intervalos Nombre intervalo simplificado Num_semitonos  \
# 10  [D3, B3, G4, E5]  [6, 4, 2]                  [M6, P4, M2]   [9, 17, 26]
# 31  [G3, E4, A4, C5]  [6, 4, 2]                  [M6, M2, P4]   [9, 14, 17]
# 34  [E3, E4, A4, C5]  [8, 6, 4]                  [P8, P4, m6]  [12, 17, 20]
#
#                         Nombre intervalo completo  Beat  Compás  Duración  \
# 10    [Major Sixth, Perfect Fourth, Major Second]  1.75       2      0.25
# 31    [Major Sixth, Major Second, Perfect Fourth]  2.50       5      0.50
# 34  [Perfect Octave, Perfect Fourth, Minor Sixth]  4.00       5      1.00
#
#        Tipo
# 10     16th
# 31   eighth
# 34  quarter

# %%
#Extraer nota del bajo de los acordes 

def extraer_bajo(dataframe):
    nuevalista = dataframe['Notas']
    bajos = []
    for lista in nuevalista:
        bajos.append(lista[0][0])

    return bajos

bajos = extraer_bajo(df_filtrado)
bajos
# Out:
# ['D', 'G', 'E']

# %%
#Histograma de los bajos

fig, ax = plt.subplots(3,1 , figsize=(10, 10))
# Plot the first histogram
plt.subplot(3, 1, 1)  # Create the first subplot (3 rows, 1 column, first position)
plt.hist(bajos, bins=16, label='Filtrado')
plt.xlabel('Nota')
plt.ylabel('Frecuencia')
plt.title('6/4')


bajos_antes = extraer_bajo(df_antes)
plt.subplot(3, 1, 2)  # Second subplot
plt.hist(bajos_antes, bins=16, label='Antes')
plt.xlabel('Nota')  # Add x-axis label for clarity
plt.ylabel('Frecuencia')
plt.title('Antes')

bajos_despues = extraer_bajo(df_despues)

plt.subplot(3, 1, 3)  # Third subplot
plt.hist(bajos_despues, bins=16, label='Despues')
plt.xlabel('Nota')  # Add x-axis label for clarity
plt.ylabel('Frecuencia')
plt.title('Despues')

plt.suptitle('Histograma de las notas del bajo', fontsize=16)
plt.subplots_adjust(hspace=0.4) 


plt.show()

# %%
bajos, bajos_antes, bajos_despues
# Out:
# (['D', 'G', 'E'], ['D', 'A', 'F'], ['E', 'F', 'D'])

# %%
def extraer_bajo_octava(dataframe):
    nuevalista = dataframe['Notas']
    bajos = []
    for lista in nuevalista:
        bajos.append(lista[0])

    return bajos

bajos_octava = extraer_bajo_octava(df_filtrado)
bajos_octava_antes = extraer_bajo_octava(df_antes)
bajos_octava_despues = extraer_bajo_octava(df_despues)

# %%
#Definir los intervalos entre en bajo antes y el bajo 6/4

from music21 import *

intervalo_antes = []


for i in range(len(bajos_octava)):
    n1 = note.Note(bajos_octava_antes[i])
    n2 = note.Note(bajos_octava[i])
    intervalo_antes.append(interval.Interval(n1, n2))

antes_64 = [ i.niceName for i in intervalo_antes]
antes_64
# Out:
# ['Perfect Unison', 'Major Second', 'Minor Second']

# %%
#Definir los intervalos entre el bajo  6/4 y el bajo después
intervalo_despues = []

for i in range(len(bajos_octava)):
    n1 = note.Note(bajos_octava[i])
    n2 = note.Note(bajos_octava_despues[i])
    intervalo_despues.append(interval.Interval(n1, n2))

[ i.niceName for i in intervalo_despues]
# Out:
# ['Major Second', 'Major Second', 'Major Second']

# %%
#Histograma de los intervalos entre los bajos 

fig, ax = plt.subplots(2,1 , figsize=(10, 10))
# Plot the first histogram
plt.subplot(2, 1, 1)  # Create the first subplot (3 rows, 1 column, first position)
plt.hist(antes_64, bins=16, label='Antes')
plt.xlabel('Intervalo')
plt.ylabel('Frecuencia')
plt.title('Antes - 6/4')


despues_64 = [ i.niceName for i in intervalo_despues]
plt.subplot(2, 1, 2)  # Second subplot
plt.hist(despues_64, bins=16, label='Despues')
plt.xlabel('Intervalo')  # Add x-axis label for clarity
plt.ylabel('Frecuencia')
plt.title('6/4 - Despues')

plt.suptitle('Histograma de los intervalos', fontsize=16)
plt.subplots_adjust(hspace=0.4)
plt.show()

# %% [markdown]
# ------------------------------------------------------------

# %%
acordes_bach = bach.acordes

nombres_itnervalos = []
for i in acordes_bach:
    notas_inter = []
    for j in range(len(i) -1):
        n1 = i[j]
        n2 = i[j+1]
        intervalo = interval.Interval(n1, n2)
        notas_inter.append(intervalo.niceName)
    nombres_itnervalos.append(notas_inter)
print(nombres_itnervalos)
# Out:
# [['Minor Tenth', 'Major Third', 'Perfect Fourth'], ['Perfect Fifth', 'Perfect Fourth', 'Minor Third'], ['Perfect Fifth', 'Perfect Fifth'], ['Minor Sixth', 'Perfect Fifth'], ['Perfect Fifth', 'Perfect Fifth', 'Minor Second'], ['Perfect Twelfth', 'Perfect Fourth', 'Minor Third'], ['Minor Tenth', 'Perfect Fifth', 'Perfect Fourth'], ['Minor Tenth', 'Perfect Fourth', 'Perfect Fifth'], ['Major Ninth', 'Perfect Fourth', 'Major Sixth'], ['Minor Seventh', 'Perfect Fifth', 'Major Sixth'], ['Major Sixth', 'Minor Sixth', 'Major Sixth'], ['Minor Sixth', 'Perfect Fifth', 'Major Sixth'], ['Perfect Fifth', 'Perfect Fifth', 'Major Sixth'], ['Major Third', 'Minor Sixth', 'Perfect Fifth'], ['Major Third', 'Diminished Fifth', 'Major Sixth'], ['Major Second', 'Perfect Fourth', 'Minor Sixth'], ['Perfect Fifth', 'Minor Sixth'], ['Perfect Fourth', 'Perfect Fifth', 'Perfect Fifth'], ['Major Third', 'Minor Sixth', 'Perfect Fifth'], ['Major Second', 'Minor Seventh', 'Perfect Fifth'], ['Major Tenth', 'Minor Six
# ...

# %%
acorde1 = bach.acordes[10]
print(acorde1)

    #Definir intervalos
    #Bajo-tenor
n1 = acorde1[0]
n2 = acorde1[1]
intervalo_tenor = interval.Interval(n1, n2)
print(intervalo_tenor.semiSimpleNiceName)

#Bajo - alto
n1 = acorde1[0]
n2 = acorde1[2]
intervalo_alto =  interval.Interval(n1, n2)
print(intervalo_alto.semiSimpleNiceName)

#Bajo - soprano
n1 = acorde1[0]
n2 = acorde1[3]
intervalo_soprano = interval.Interval(n1, n2)
print(intervalo_soprano.semiSimpleName)
# Out:
# <music21.chord.Chord D3 B3 G4 E5>
# Major Sixth
# Perfect Fourth
# M2
