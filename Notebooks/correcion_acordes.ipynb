# %%
from clase import cuartas 
from clasificacion_solo4 import *
from clasificacion import *
import glob 
import os
import music21
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
xml_file = '../Archivos/Corales/corales_completo/024864Bs.xml'
# xml_file = '../Archivos/Corales/corales_completo/024511B_.xml'

# %%
solo4 = cuartas(xml_file)
df_4 = solo4.extraer_df()

# %%
ind, df_fil4  = encontrar_4(df_4)

# %%
df_fil4 = df_fil4.rename(columns={'Notas': 'Acordes'})
df_fil4['Solo 4tas'] = '1'
df_fil4
# Out:
#                Acordes Intervalos Nombre intervalo simplificado Num_semitonos  \
# 6        [A3, D4, F#4]     [6, 4]                      [P4, M6]        [5, 9]
# 9    [E3, A3, C#4, E4]  [8, 6, 4]                  [P4, M6, P8]    [5, 9, 12]
# 14  [F#3, F#4, B4, D5]  [8, 6, 4]                  [P8, P4, m6]  [12, 17, 20]
# 30       [A3, D4, F#4]     [6, 4]                      [P4, M6]        [5, 9]
# 33   [E3, A3, C#4, E4]  [8, 6, 4]                  [P4, M6, P8]    [5, 9, 12]
# 38  [F#3, F#4, B4, D5]  [8, 6, 4]                  [P8, P4, m6]  [12, 17, 20]
# 48    [A3, E4, B4, D5]  [5, 4, 2]                  [P5, M2, P4]   [7, 14, 17]
# 53    [D3, D4, G4, A4]  [8, 5, 4]                  [P8, P4, P5]  [12, 17, 19]
# 56   [F#3, D4, G4, B4]  [6, 4, 2]                  [m6, m2, P4]   [8, 13, 17]
# 60   [A3, D4, F#4, D5]  [6, 4, 4]                  [P4, M6, P4]    [5, 9, 17]
# 92        [A3, D4, E4]     [5, 4]                      [P4, P5]        [5, 7]
#
#                           Nombre intervalo completo  Beat  Compás  Duración  \
# 6                     [Perfect Fourth, Major Sixth]   4.0       1      1.00
# 9     [Perfect Fourth, Major Sixth, Perfect Octave]   2.0       2      0.50
# 14    [Perfect Octave, Perfect Fourth, Minor Sixth]   1.5       3      0.50
# 30                    [Perfect Fourth, Major Sixth]   4.0       5      1.00
# 33    [Perfect Fourth, Major Sixth, Perfect Octave]   2.0       6      0.50
# 38    [Perfect Octave, Perfect Fourth, Minor Sixth]   1.5       7      0.50
# 48    [Perfect Fifth, Major Second, Perfect Fourth]   4.0       8      0.50
# 53  [Perfect Octave, Perfect Fourth, Perfect Fifth]   2.5       9      0.25
# 56      [Minor Sixth, Minor Second, Perfect Fourth]   3.5       9      0.50
# 60    [Perfect Fourth, Major Sixth, Perfect Fourth]   1.5      10      0.50
# 92                  [Perfect Fourth, Perfect Fifth]   3.0      15      0.50
#
#        Tipo Solo 4tas
# 6   quarter         1
# 9    eighth         1
# 14   eighth         1
# 30  quarter         1
# 33   eighth         1
# 38   eighth         1
# 48   eighth         1
# 53     16th         1
# 56   eighth         1
# 60   eighth         1
# 92   eighth         1

# %%
#Solo columnas de interes 

df_fil4 = df_fil4[['Acordes','Solo 4tas']]

# %%
dataframe_clasificacion(df_fil4)
# Out:
# /home/cuba/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3789         try:
# -> 3790             return self._engine.get_loc(casted_key)
#    3791         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nombre intervalo simplificado'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_21774/1650669230.py in <module>
# ----> 1 dataframe_clasificacion(df_fil4)
#
# ~/Documents/UNIVERSIDAD/M_C/Notebooks/clasificacion.py in dataframe_clasificacion(dataframe)
#     869     #----------------------------------------
#     870     #Clasificación de los acordes 6/4 de paso
# --> 871     df_paso = acorde6_4_paso(dataframe)
#     872     df_paso.rename(columns={'Suma': 'Suma_paso (n/4)'}, inplace=True)
#     873     # df_paso['#'] = df_paso.index + 1  #Para que arranque en 1
#
# ~/Documents/UNIVERSIDAD/M_C/Notebooks/clasificacion.py in acorde6_4_paso(dataframe)
#     762
#     763     #Encontrar los acordes 6/4
# --> 764     indices, df_filtrado = encontrar_64(dataframe)
#     765
#     766     #Extraer las notas del bajo de los acordes 6/4
#
# ~/Documents/UNIVERSIDAD/M_C/Notebooks/clasificacion.py in encontrar_64(dataframe)
#      36   """
#      37
# ---> 38   nuevalista = dataframe['Nombre intervalo simplificado']
#      39   indices = []
#      40   for indice, lista in enumerate(nuevalista):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3795             ):
#    3796                 raise InvalidIndexError(key)
# -> 3797             raise KeyError(key) from err
#    3798         except TypeError:
#    3799             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Nombre intervalo simplificado'

# %%
df_fil4
# Out:
#                Acordes Solo 4tas
# 6        [A3, D4, F#4]         1
# 9    [E3, A3, C#4, E4]         1
# 14  [F#3, F#4, B4, D5]         1
# 30       [A3, D4, F#4]         1
# 33   [E3, A3, C#4, E4]         1
# 38  [F#3, F#4, B4, D5]         1
# 48    [A3, E4, B4, D5]         1
# 53    [D3, D4, G4, A4]         1
# 56   [F#3, D4, G4, B4]         1
# 60   [A3, D4, F#4, D5]         1
# 92        [A3, D4, E4]         1

# %%
len(df_fil4)
# Out:
# 11

# %%
df_estoy = dataframe_clasificacion(df_4)

# %%
df_estoy.drop_duplicates(subset=['Acordes'], keep='first', inplace=True)

len(df_estoy)
# Out:
# 5

# %%
df_nuevo = pd.DataFrame


#acordes a string

df_fil4 =acordes_to_string(df_fil4)

df_nuevo = pd.merge(df_estoy, df_fil4, on='Acordes', how='right')
# Out:
# /home/cuba/Documents/UNIVERSIDAD/M_C/Notebooks/clasificacion.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Acordes'] = df['Acordes'].apply(lambda x: str(x) if isinstance(x, list) else x)

# %%
df_fil4
# Out:
#                        Acordes Solo 4tas
# 6          ['A3', 'D4', 'F#4']         1
# 9    ['E3', 'A3', 'C#4', 'E4']         1
# 14  ['F#3', 'F#4', 'B4', 'D5']         1
# 30         ['A3', 'D4', 'F#4']         1
# 33   ['E3', 'A3', 'C#4', 'E4']         1
# 38  ['F#3', 'F#4', 'B4', 'D5']         1
# 48    ['A3', 'E4', 'B4', 'D5']         1
# 53    ['D3', 'D4', 'G4', 'A4']         1
# 56   ['F#3', 'D4', 'G4', 'B4']         1
# 60   ['A3', 'D4', 'F#4', 'D5']         1
# 92          ['A3', 'D4', 'E4']         1

# %%
df_nuevo.drop_duplicates(subset='Acordes', keep='first', inplace=True)
df_nuevo
# Out:
#                        Acordes  Compás  Beat  Duración  Suma_paso (n/4)  \
# 0          ['A3', 'D4', 'F#4']     1.0   4.0       1.0              2.0
# 1    ['E3', 'A3', 'C#4', 'E4']     2.0   2.0       0.5              0.0
# 2   ['F#3', 'F#4', 'B4', 'D5']     3.0   1.5       0.5              2.0
# 6     ['A3', 'E4', 'B4', 'D5']     NaN   NaN       NaN              NaN
# 7     ['D3', 'D4', 'G4', 'A4']     NaN   NaN       NaN              NaN
# 8    ['F#3', 'D4', 'G4', 'B4']     9.0   3.5       0.5              3.0
# 9    ['A3', 'D4', 'F#4', 'D5']    10.0   1.5       0.5              3.0
# 10          ['A3', 'D4', 'E4']     NaN   NaN       NaN              NaN
#
#     Suma_cadencial (n/4)  Suma_bordadura (n/3) Clasificación Solo 4tas
# 0                    1.0                   0.0            NI         1
# 1                    1.0                   0.0            NI         1
# 2                    1.0                   0.0            NI         1
# 6                    NaN                   NaN           NaN         1
# 7                    NaN                   NaN           NaN         1
# 8                    1.0                   0.0            NI         1
# 9                    1.0                   0.0            NI         1
# 10                   NaN                   NaN           NaN         1

# %% [markdown]
# -----------------------

# %%
error1 = cuartas(xml_file)

# %%
error1.mostrar_partitura()

# %%
error1.chordify()
error1.mostrar_partitura()

# %%
df_error = error1.extraer_df()

# %%
df_error.head(10)
# Out:
#                 Notas Intervalos Nombre intervalo simplificado Num_semitonos  \
# 0   [D3, A3, D4, F#4]  [8, 5, 3]                  [P5, P8, M3]   [7, 12, 16]
# 1    [G3, B3, D4, B4]  [5, 3, 3]                  [M3, P5, M3]    [4, 7, 16]
# 2   [G3, C#4, E4, B4]  [6, 4, 3]                  [A4, M6, M3]    [6, 9, 16]
# 3  [F#3, D4, F#4, A4]  [8, 6, 3]                  [m6, P8, m3]   [8, 12, 15]
# 4        [G3, B3, G4]     [8, 3]                      [M3, P8]       [4, 12]
# 5   [G3, B3, C#4, G4]  [8, 4, 3]                  [M3, A4, P8]    [4, 6, 12]
# 6       [A3, D4, F#4]     [6, 4]                      [P4, M6]        [5, 9]
# 7    [G3, B3, D4, E4]  [6, 5, 3]                  [M3, P5, M6]     [4, 7, 9]
# 8        [G3, D4, E4]     [6, 5]                      [P5, M6]        [7, 9]
# 9   [E3, A3, C#4, E4]  [8, 6, 4]                  [P4, M6, P8]    [5, 9, 12]
#
#                          Nombre intervalo completo  Beat  Compás  Duración  \
# 0     [Perfect Fifth, Perfect Octave, Major Third]   4.0       0       1.0
# 1        [Major Third, Perfect Fifth, Major Third]   1.0       1       0.5
# 2     [Augmented Fourth, Major Sixth, Major Third]   1.5       1       0.5
# 3       [Minor Sixth, Perfect Octave, Minor Third]   2.0       1       1.0
# 4                    [Major Third, Perfect Octave]   3.0       1       0.5
# 5  [Major Third, Augmented Fourth, Perfect Octave]   3.5       1       0.5
# 6                    [Perfect Fourth, Major Sixth]   4.0       1       1.0
# 7        [Major Third, Perfect Fifth, Major Sixth]   1.0       2       0.5
# 8                     [Perfect Fifth, Major Sixth]   1.5       2       0.5
# 9    [Perfect Fourth, Major Sixth, Perfect Octave]   2.0       2       0.5
#
#       Tipo
# 0  quarter
# 1   eighth
# 2   eighth
# 3  quarter
# 4   eighth
# 5   eighth
# 6  quarter
# 7   eighth
# 8   eighth
# 9   eighth
